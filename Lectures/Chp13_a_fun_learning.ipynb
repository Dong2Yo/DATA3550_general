# %% [markdown]
# <a href="https://colab.research.google.com/github/Dong2Yo/DATA3550_1232/blob/main/Lectures/Chp13_a_fun_learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Chapter 13 Sorting & Searching

# %% [markdown]
# ## DuckTyping

# %% [markdown]
# Duck typing is a concept used in dynamic programming languages like Python. It's a way to determine an object's type based on its behavior rather than its actual type. The term "If it looks like a duck and quacks like a duck, it must be a duck" is often used to explain this concept.
#
# In Python, duck typing allows you to use an object based on what methods or attributes it has, rather than its actual type. This means you can perform operations on objects as long as they support the required methods or attributes, without needing to check their explicit type.

# %%
import random

# %% [markdown]
# ## Improving Performance

# %% [markdown]
# ### Big O Notation

# %% [markdown]
# **Big O notation is a mathematical notation used in computer science to describe the time complexity or space complexity of an algorithm. It represents the upper bound of the growth rate of a function, indicating how the runtime or space requirements of an algorithm increase as the size of the input data increases.**
#
# In simpler terms, Big O notation gives us an idea of how an algorithm performs as the size of the input grows. It allows us to compare different algorithms and analyze their efficiency.

# %% [markdown]
# Here are some common Big O complexities and their meanings:
#
# - O(1) - Constant time complexity: The runtime of the algorithm does not depend on the size of the input. For example, accessing an element in an array by index.
#
# - O(log n) - Logarithmic time complexity: The runtime of the algorithm grows logarithmically as the size of the input increases. For example, binary search on a sorted array.
#
# - O(n) - Linear time complexity: The runtime of the algorithm grows linearly with the size of the input. For example, iterating through each element in a list.
#
# - O(n log n) - Linearithmic time complexity: The runtime of the algorithm grows in proportion to n multiplied by the logarithm of n. For example, efficient sorting algorithms like Merge Sort and Quick Sort.
#
# - O(n^2) - Quadratic time complexity: The runtime of the algorithm grows quadratically with the size of the input. For example, nested loops where each loop iterates over the size of the input.
#
# - O(2^n) - Exponential time complexity: The runtime of the algorithm doubles with each additional input element. For example, recursive algorithms with branching factor of 2.

# %%
# Define the function to sum the elements of a list
def sum_of_list(lst):
    total = 0
    for num in lst:
        total += num
    return total
my_list = [1, 2, 3, 4, 5]
sum_of_list(my_list)

# %% [markdown]
# We'll iterate through each element in the list and check if it's even.

# %% [markdown]
# ***For Loop***

# %% [markdown]
# ***List Comprehension***

# %% [markdown]
# ***Checking Performance***

# %% [markdown]
# ## Sorting

# %%
sort_list = [6, 5, 3, 1, 8, 7, 2, 4]

# %% [markdown]
# ### Bubble Sort

# %% [markdown]
# Bubble sort repeatedly steps through the list, compares adjacent elements, and swaps them if they are in the wrong order. The process repeats until the list is sorted.

# %% [markdown]
# ![Bubble-sort-example-300px.gif](data:image/gif;base64,...)

# %% [markdown]
# [Bubble Sort](https://miro.medium.com/v2/resize:fit:640/format:webp/1*7seGXJi3te9beNfpAvFXEQ.gif)

# %%
# @title Bubble Sort
def bubble_sort(arr):
    n = len(arr)
    for i in range(n):
        for j in range(0, n-i-1):
            if arr[j] > arr[j+1]:
                arr[j], arr[j+1] = arr[j+1], arr[j]
    return arr


print("Sorted array using Bubble Sort:", bubble_sort(sort_list))

# %% [markdown]
# ### Selection Sort

# %% [markdown]
# Selection sort divides the input list into two parts: a sorted sublist and an unsorted sublist. It repeatedly selects the smallest (or largest) element from the unsorted sublist and moves it to the end of the sorted sublist.

# %% [markdown]
# ![selectionSort.gif](data:image/gif;base64,...)

# %%
# @title Selection Sort
def selection_sort(arr):
    n = len(arr)
    for i in range(n):
        min_idx = i
        for j in range(i+1, n):
            if arr[j] < arr[min_idx]:
                min_idx = j
        arr[i], arr[min_idx] = arr[min_idx], arr[i]
    return arr


print("Sorted array using Selection Sort:", selection_sort(sort_list))

# %% [markdown]
# ### Insertion Sort

# %% [markdown]
# Insertion sort builds the final sorted list one item at a time by iteratively removing elements from the input data and inserting them into the correct position in the sorted list.

# %% [markdown]
# ![Insertion-sort-example-300px.gif](data:image/gif;base64,...)

# %%
# @title Insertion Sort

def insertion_sort(arr):
    for i in range(1, len(arr)):
        key = arr[i]
        j = i-1
        while j >=0 and key < arr[j]:
            arr[j+1] = arr[j]
            j -= 1
        arr[j+1] = key
    return arr


print("Sorted array using Insertion Sort:", insertion_sort(sort_list))

# %% [markdown]
# ### Merge Sort

# %% [markdown]
# Merge sort is a divide-and-conquer algorithm that divides the input list into two halves, recursively sorts each half, and then merges the sorted halves.

# %% [markdown]
# ![Merge-sort-example-300px.gif](data:image/gif;base64,...)

# %%
# @title Merge Sort
def merge_sort(arr):
    if len(arr) > 1:
        mid = len(arr) // 2
        L = arr[:mid]
        R = arr[mid:]

        merge_sort(L)
        merge_sort(R)

        i = j = k = 0

        while i < len(L) and j < len(R):
            if L[i] < R[j]:
                arr[k] = L[i]
                i += 1
            else:
                arr[k] = R[j]
                j += 1
            k += 1

        while i < len(L):
            arr[k] = L[i]
            i += 1
            k += 1

        while j < len(R):
            arr[k] = R[j]
            j += 1
            k += 1

    return arr

print("Sorted array using Merge Sort:", merge_sort(sort_list))

# %% [markdown]
# ### Quick Sort

# %% [markdown]
# Quick sort is another divide-and-conquer algorithm that selects a pivot element and partitions the input list into two sublists, one containing elements less than the pivot and the other containing elements greater than the pivot. It then recursively sorts the sublists.

# %% [markdown]
# ![Quicksort-example.gif](data:image/gif;base64,...)

# %%
# @title Quick Sort
def quick_sort(arr):
    if len(arr) <= 1:
        return arr
    else:
        pivot = arr[0]
        less_than_pivot = [x for x in arr[1:] if x <= pivot]
        greater_than_pivot = [x for x in arr[1:] if x > pivot]
        return quick_sort(less_than_pivot) + [pivot] + quick_sort(greater_than_pivot)


print("Sorted array using Quick Sort:", quick_sort(sort_list))

# %% [markdown]
# ## Business Case & Performance

# %% [markdown]
# **Measure Performance**
