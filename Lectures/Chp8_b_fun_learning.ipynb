# %% [markdown]
# <a href="https://colab.research.google.com/github/Dong2Yo/DATA3550_1232/blob/main/Lectures/Chp8_b_fun_learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Chp8_b Fun Learning

# %% [markdown]
# ## Q1
#
# In a store, we have a list of products and their sales counts. We want to find out which products have sold more than 100 units.

# %%
# Sample data representing products and their sales counts
sales_data = {
    'Product A': 150,
    'Product B': 80,
    'Product C': 200,
    'Product D': 120,
    'Product E': 90
}

# %% [markdown]
# ## Q2

# %% [markdown]
# In a retail chain, we have sales data for multiple stores across different regions. We want to identify the top-performing region in terms of revenue and find the product that contributed the most to that region's revenue.

# %%
# Sample sales data representing stores, regions, products, and revenue
sales_data = [
    {"Store": "Store A", "Region": "North", "Product": "Product A", "Revenue": 5000},
    {"Store": "Store B", "Region": "South", "Product": "Product B", "Revenue": 8000},
    {"Store": "Store C", "Region": "North", "Product": "Product C", "Revenue": 6000},
    {"Store": "Store D", "Region": "West", "Product": "Product A", "Revenue": 10000},
    {"Store": "Store E", "Region": "East", "Product": "Product D", "Revenue": 7000},
    {"Store": "Store F", "Region": "South", "Product": "Product E", "Revenue": 9000},
    {"Store": "Store G", "Region": "East", "Product": "Product A", "Revenue": 8500},
]

# %% [markdown]
# > It utilizes dictionaries to aggregate revenue by region and product and then identifies the top-performing region and the product contributing the most to its revenue. Finally, it displays the results.

# %% [markdown]
# ## Q3

# %% [markdown]
# In a multinational company, we have sales data from different regions stored in dictionaries. We want to find out the total revenue generated by each product across all regions.

# %%
sales_data = {
    'Region A': {'Product A': 150, 'Product B': 80, 'Product C': 200},
    'Region B': {'Product A': 120, 'Product B': 90, 'Product C': 180},
    'Region C': {'Product A': 100, 'Product B': 110, 'Product C': 160}
}

# %% [markdown]
# This question involves processing sales data from multiple regions stored in dictionaries.
#
# The task is to find the total revenue generated by each product across all regions.
#
# >The code iterates through the nested dictionaries representing sales data and accumulates the total revenue for each product. Finally, it displays the total revenue for each product. This question is more challenging as it involves working with nested data structures and performing calculations across multiple data sources.

# %% [markdown]
# ## Q4

# %%
# Load the dataset into a Python list of dictionaries
data = [
    {"Customer ID": 1, "Product ID": 101, "Product Name": "Product A", "Quantity": 2},
    {"Customer ID": 2, "Product ID": 102, "Product Name": "Product B", "Quantity": 6},
    {"Customer ID": 1, "Product ID": 103, "Product Name": "Product C", "Quantity": 3},
    {"Customer ID": 3, "Product ID": 101, "Product Name": "Product C", "Quantity": 8},
    {"Customer ID": 2, "Product ID": 102, "Product Name": "Product B", "Quantity": 9},
    {"Customer ID": 3, "Product ID": 103, "Product Name": "Product C", "Quantity": 13},
]

# %% [markdown]
# ### Customer Preferences Analysis
# Create a dictionary to store customer preferences based on their purchase history

# %% [markdown]
# ### Frequently Purchased Items
#
# Identify the most frequently purchased items overall

# %% [markdown]
# ### Determine the association between frequently purchased items using sets

# %% [markdown]
# ### Customer Behavior Analysis
# Analyze the purchasing behavior of different customer segments

# %% [markdown]
# ### Summary
