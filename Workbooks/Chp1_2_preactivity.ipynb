# %% [markdown]
# <a href="https://colab.research.google.com/github/Dong2Yo/DATA3550_1232/blob/main/Workbooks/Chp1_2_preactivity.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Instructions**
#
# *   Work with your break out room members on the Activity;
# *   Please have only **ONE member** write the program in the notebook;
# *   Share by allowing editing.
# *   Publish the URL in the chat in the following format:
#
#             Breakout Room # : URL

# %% [markdown]
# # Chapter 1_2 Pre-activity One

# %% [markdown]
# Invite the user to enter three adjectives;
#
# Ask the user to enter the first name;
#
# Print the statement as follows:
#
# ![Wk1_activity_2.GIF](data:image/gif;base64,...)

# %% [markdown]
# # Chapter 1_2 Pre-activity Two

# %% [markdown]
# Write a program that prints a house that looks exactly like the following:
#
# 			      +
# 			     + +
# 			    +   +
# 			   +-----+
# 			   | .-. |
# 			   | | | |
# 			   +-+-+-+
