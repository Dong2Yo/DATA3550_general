# %% [markdown]
# <a href="https://colab.research.google.com/github/Dong2Yo/DATA3550_1232/blob/main/Workbooks/Chp1_1_inClass_Ex_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Instructions**
#
# *   Work with your break out room members on the Activity;
# *   Please have only **ONE member** write the program in the notebook;
# *   Share by allowing editing.
# *   Publish the URL in the chat in the following format:
#
#             Breakout Room # : URL

# %% [markdown]
# # Chapter 1_1 InClass Ex One

# %% [markdown]
# Write a program that prints a statement to decribe your feelings using three adjectives in the format of
#             **We am current very ..., ..., and ...**
# Please also identify the statement with all of your first names.

# %%
# Breakout Room X

# %% [markdown]
# What about asking for input?
#
# Something like
#
# ![Screenshot 2021-09-08 172608.jpg](data:image/jpeg;base64,...)
