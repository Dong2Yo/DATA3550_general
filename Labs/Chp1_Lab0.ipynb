# %% [markdown]
# <a href="https://colab.research.google.com/github/Dong2Yo/DATA3550_1232/blob/main/Labs/Chp1_Lab0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Instructions** :
#
# *   Please work on the Lab session questions within Google Colab;
# *   When promted to save the edited notebook, you would find
#
# ![1.jpg](data:image/jpeg;base64,...)
#
# *  **You can, however, save a local copy of the updated notebook;**
#
# ![2.jpg](data:image/jpeg;base64,...)
#
# *   Please name the notebook as Chp1_Lab0_FirstLastname;
# *   Upload the notebook to your Google Colab;
# *   Share your document with a generated URL;
# *   Submit the URL to the Workshop Lab 0 on Moodle.

# %% [markdown]
# **1. Assume John is paid at $20/hour and works 40 hours/week for 50 weeks annually. Please write a program that prints the annual salary as well as the monthly salary with 2 decimal places.** (30%)

# %%
hourly_wage = 20

print('Annual salary is: ')
print(hourly_wage * 40 * 50)
print()

print('Monthly salary is: ')
print(((hourly_wage * 40 * 52) / 1))
print()

# FIXME: The above is wrong.
# Out:
# Annual salary is:
# 40000
#
# Monthly salary is:
# 41600.0

# %% [markdown]
# **2. Print a tree by adding a base under a 4-level triangle:** (30%)
#
# ![Screenshot 2021-09-08 161453.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# **3. Write a program that prints an animal speaking a greeting, similar to (but different from) the following:** (40%)
#
# 			 /\_/\     -----
# 			( ' ' )  / Hello \
# 			(  -  ) <  Junior |
# 			 | | |   \ Coder!/
# 			(__|__)    -----
